# %%
import drawFigures as dF
import numpy as np
import h5py
import pandas as pd
import os.path

# %% [markdown]
# ## Reading hdf5 file

# %%
raw_data =pd.read_hdf("vna_amp_n.h5")#prueba2 con -25dbm, 3 con -15, 4 con -20,5 con -30

# %%
raw_data
# Out:
#                   0                   1                   2    \
# 0  0.003527-0.003120j -0.020064+0.007076j -0.047683+0.047065j
#
#                   3                   4                   5    \
# 0  0.004184+0.050827j  0.028556+0.052782j  0.004617-0.013553j
#
#                   6                   7                   8    \
# 0  0.009782+0.058768j  0.013997+0.042658j  0.061587+0.017196j
#
#                   9    ...                 290                 291  \
# 0  0.011940-0.010344j  ...  0.058533+0.008002j -0.008394-0.032696j
#
#                   292                 293                 294  \
# 0 -0.024609+0.018837j  0.029318+0.045310j  0.026259-0.024900j
#
#                   295                 296                 297  \
# 0 -0.013475-0.006010j -0.008304+0.038208j  0.054975+0.016404j
#
#                   298                 299
# 0  0.024606-0.030723j -0.008218-0.025853j
#
# [1 rows x 300 columns]

# %% [markdown]
# ## Obtaining the range profile

# %%
dF.rangeProfile(15, 0.5, raw_data.T[0])
# Out:
# 'ok'

# %%
dr = round(0.3/(2*0.2),2)
dr
# Out:
# 0.75

# %%
dr*100
# Out:
# 75.0

# %%
200/400
# Out:
# 0.5
